# %%
import numpy as np
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt

# %%
np.random.seed(1)
x = np.arange(5)
y = np.random.randn(5)

fig, axes = plt.subplots(ncols=2, figsize=plt.figaspect(1./2))

vert_bars = axes[0].bar(x, y, color='lightblue', align='center')
horiz_bars = axes[1].barh(x, y, color='lightblue', align='center')

axes[0].axhline(0, color='gray', linewidth=2)
axes[1].axvline(0, color='gray', linewidth=2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
print(y)
# Out:
# [ 1.62434536 -0.61175641 -0.52817175 -1.07296862  0.86540763]

# %%
fig, ax = plt.subplots()
vert_bars = ax.bar(x, y, color='lightblue', align='center')

for bar, height in zip(vert_bars, y):
    if height < 0:
        bar.set(edgecolor='darkred', color='green', linewidth=3)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.random.seed(1)
y = np.random.randn(100).cumsum()
x = np.linspace(0, 10, 100)

fig, ax = plt.subplots(ncols=2, figsize=plt.figaspect(1./2))
ax[0].plot(x, y, color='lightblue')
ax[1].fill_between(x, y, color='lightgreen')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
x = np.linspace(0, 10, 200)
y1 = 2 * x + 1
y2 = 3 * x + 1.2

y_mean = 0.5 * x * np.sin(2*x) + 2.5 * x + 1.1

fig, ax = plt.subplots()

ax.fill_between(x, y1, y2, color='yellow')

ax.plot(x, y_mean, color='black')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.linspace(0, 10, 200)
data_obj = {
    'x': x,
    'y1': 2 * x + 1,
    'y2': 3 * x + 1.2,
    'mean': 0.5 * x * np.cos(2*x) + 2.5 * x + 1.1
}

fig, ax = plt.subplots()

ax.fill_between('x', 'y1', 'y2', color='yellow', data=data_obj)

ax.plot('x', 'mean', color='black', data=data_obj)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.random.seed(1)

y_raw = np.random.randn(1000).cumsum() + 15
x_raw= np.linspace(0, 24, y_raw.size)

# %%
y_raw.size
# Out:
# 1000

# %%
x_raw
# Out:
# array([ 0.        ,  0.02402402,  0.04804805,  0.07207207,  0.0960961 ,
#         0.12012012,  0.14414414,  0.16816817,  0.19219219,  0.21621622,
#         0.24024024,  0.26426426,  0.28828829,  0.31231231,  0.33633634,
#         0.36036036,  0.38438438,  0.40840841,  0.43243243,  0.45645646,
#         0.48048048,  0.5045045 ,  0.52852853,  0.55255255,  0.57657658,
#         0.6006006 ,  0.62462462,  0.64864865,  0.67267267,  0.6966967 ,
#         0.72072072,  0.74474474,  0.76876877,  0.79279279,  0.81681682,
#         0.84084084,  0.86486486,  0.88888889,  0.91291291,  0.93693694,
#         0.96096096,  0.98498498,  1.00900901,  1.03303303,  1.05705706,
#         1.08108108,  1.10510511,  1.12912913,  1.15315315,  1.17717718,
#         1.2012012 ,  1.22522523,  1.24924925,  1.27327327,  1.2972973 ,
#         1.32132132,  1.34534535,  1.36936937,  1.39339339,  1.41741742,
#         1.44144144,  1.46546547,  1.48948949,  1.51351351,  1.53753754,
# ...

# %%
x_pos = x_raw.reshape(-1, 100).min(axis=1)
x_pos
# Out:
# array([ 0.        ,  2.4024024 ,  4.8048048 ,  7.20720721,  9.60960961,
#        12.01201201, 14.41441441, 16.81681682, 19.21921922, 21.62162162])

# %%
x_raw.reshape(-1, 100)
# Out:
# array([[ 0.        ,  0.02402402,  0.04804805,  0.07207207,  0.0960961 ,
#          0.12012012,  0.14414414,  0.16816817,  0.19219219,  0.21621622,
#          0.24024024,  0.26426426,  0.28828829,  0.31231231,  0.33633634,
#          0.36036036,  0.38438438,  0.40840841,  0.43243243,  0.45645646,
#          0.48048048,  0.5045045 ,  0.52852853,  0.55255255,  0.57657658,
#          0.6006006 ,  0.62462462,  0.64864865,  0.67267267,  0.6966967 ,
#          0.72072072,  0.74474474,  0.76876877,  0.79279279,  0.81681682,
#          0.84084084,  0.86486486,  0.88888889,  0.91291291,  0.93693694,
#          0.96096096,  0.98498498,  1.00900901,  1.03303303,  1.05705706,
#          1.08108108,  1.10510511,  1.12912913,  1.15315315,  1.17717718,
#          1.2012012 ,  1.22522523,  1.24924925,  1.27327327,  1.2972973 ,
#          1.32132132,  1.34534535,  1.36936937,  1.39339339,  1.41741742,
#          1.44144144,  1.46546547,  1.48948949,  1.51351351,  1.53753754,
# ...

# %%
x_raw.reshape(-1, 100).shape
# Out:
# (10, 100)

# %%
x_pos.shape
# Out:
# (10,)

# %%
y_avg = y_raw.reshape(-1, 100).mean(axis = 1)

# %%
y_avg.shape
# Out:
# (10,)

# %%
y_raw.shape
# Out:
# (1000,)

# %%
x_raw.shape
# Out:
# (1000,)

# %%
y_err = y_raw.reshape(-1, 100).ptp(axis=1)
y_err
# Out:
# array([13.01387279, 18.5648245 ,  9.13387598, 13.03480471, 15.80752631,
#        16.4573516 ,  8.91922797, 13.79108878, 19.5640873 , 13.62594585])

# %%
x_pos
# Out:
# array([ 0.        ,  2.4024024 ,  4.8048048 ,  7.20720721,  9.60960961,
#        12.01201201, 14.41441441, 16.81681682, 19.21921922, 21.62162162])

# %%
print(x_pos[0], x_pos[1])
# Out:
# 0.0 2.4024024024024024

# %%
bar_width = x_pos[1] - x_pos[0]

# %%
x_pred = np.linspace(0, 30)
y_max_pred = y_avg[0] + y_err[0] + 2.3 * x_pred
y_min_pred = y_avg[0] - y_err[0] + 1.2 * x_pred

# %%
y_max_pred
# Out:
# array([28.28869757, 29.69686084, 31.1050241 , 32.51318737, 33.92135064,
#        35.3295139 , 36.73767717, 38.14584043, 39.5540037 , 40.96216696,
#        42.37033023, 43.77849349, 45.18665676, 46.59482002, 48.00298329,
#        49.41114655, 50.81930982, 52.22747308, 53.63563635, 55.04379961,
#        56.45196288, 57.86012615, 59.26828941, 60.67645268, 62.08461594,
#        63.49277921, 64.90094247, 66.30910574, 67.717269  , 69.12543227,
#        70.53359553, 71.9417588 , 73.34992206, 74.75808533, 76.16624859,
#        77.57441186, 78.98257513, 80.39073839, 81.79890166, 83.20706492,
#        84.61522819, 86.02339145, 87.43155472, 88.83971798, 90.24788125,
#        91.65604451, 93.06420778, 94.47237104, 95.88053431, 97.28869757])

# %%
y_min_pred
# Out:
# array([ 2.26095199,  2.99564587,  3.73033975,  4.46503363,  5.19972751,
#         5.93442138,  6.66911526,  7.40380914,  8.13850302,  8.87319689,
#         9.60789077, 10.34258465, 11.07727853, 11.8119724 , 12.54666628,
#        13.28136016, 14.01605404, 14.75074791, 15.48544179, 16.22013567,
#        16.95482955, 17.68952342, 18.4242173 , 19.15891118, 19.89360506,
#        20.62829893, 21.36299281, 22.09768669, 22.83238057, 23.56707444,
#        24.30176832, 25.0364622 , 25.77115608, 26.50584995, 27.24054383,
#        27.97523771, 28.70993159, 29.44462546, 30.17931934, 30.91401322,
#        31.6487071 , 32.38340097, 33.11809485, 33.85278873, 34.58748261,
#        35.32217648, 36.05687036, 36.79156424, 37.52625812, 38.26095199])

# %%
y_min_pred.shape
# Out:
# (50,)

# %%
x_pred.shape
# Out:
# (50,)

# %%
x_pred
# Out:
# array([ 0.        ,  0.6122449 ,  1.2244898 ,  1.83673469,  2.44897959,
#         3.06122449,  3.67346939,  4.28571429,  4.89795918,  5.51020408,
#         6.12244898,  6.73469388,  7.34693878,  7.95918367,  8.57142857,
#         9.18367347,  9.79591837, 10.40816327, 11.02040816, 11.63265306,
#        12.24489796, 12.85714286, 13.46938776, 14.08163265, 14.69387755,
#        15.30612245, 15.91836735, 16.53061224, 17.14285714, 17.75510204,
#        18.36734694, 18.97959184, 19.59183673, 20.20408163, 20.81632653,
#        21.42857143, 22.04081633, 22.65306122, 23.26530612, 23.87755102,
#        24.48979592, 25.10204082, 25.71428571, 26.32653061, 26.93877551,
#        27.55102041, 28.16326531, 28.7755102 , 29.3877551 , 30.        ])

# %%
barcolor, linecolor, fillcolor = 'wheat', 'salmon', 'lightblue'

# %%
fig, ax = plt.subplots()
ax.plot(x_raw, y_raw, color=linecolor)
ax.bar(x_pos, y_avg, color=barcolor, width=bar_width, yerr=y_err, ecolor='gray', edgecolor='gray')
ax.fill_between(x_pred, y_min_pred, y_max_pred, color=fillcolor)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = np.load('bivariate_normal.npy')

fig, ax = plt.subplots()
im = ax.imshow(data, cmap='gist_earth')
fig.colorbar(im)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])

im = ax.imshow(data, cmap='gist_earth')
fig.colorbar(im, cax=cax, orientation='horizontal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
im = ax.imshow(data, cmap='seismic')
fig.colorbar(im)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
