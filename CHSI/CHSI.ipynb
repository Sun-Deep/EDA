# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./chsi_dataset/RELATIVEHEALTHIMPORTANCE.csv')
df.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
# 3                1                 7             Bibb         Alabama
# 4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  RHI_LBW_Ind  RHI_VLBW_Ind  \
# 0              AL                29            8             8
# 1              AL                16            8             8
# 2              AL                51            8             8
# 3              AL                42            8             8
# 4              AL                28            7             8
#
#    RHI_Premature_Ind  RHI_Under_18_Ind  ...  RHI_IM_Postneonatal_Ind  \
# 0                  8                 8  ...                        8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 28 columns):
# State_FIPS_Code             3141 non-null int64
# County_FIPS_Code            3141 non-null int64
# CHSI_County_Name            3141 non-null object
# CHSI_State_Name             3141 non-null object
# CHSI_State_Abbr             3141 non-null object
# Strata_ID_Number            3141 non-null int64
# RHI_LBW_Ind                 3141 non-null int64
# RHI_VLBW_Ind                3141 non-null int64
# RHI_Premature_Ind           3141 non-null int64
# RHI_Under_18_Ind            3141 non-null int64
# RHI_Over_40_Ind             3141 non-null int64
# RHI_Unmarried_Ind           3141 non-null int64
# RHI_Late_Care_Ind           3141 non-null int64
# RHI_Infant_Mortality_Ind    3141 non-null int64
# RHI_IM_Wh_Non_Hisp_Ind      3141 non-null int64
# RHI_IM_Bl_Non_Hisp_Ind      3141 non-null int64
# RHI_IM_Hisp_Ind             3141 non-null int64
# ...

# %%
df.shape
# Out:
# (3141, 28)

# %%
df.describe()
# Out:
#        State_FIPS_Code  County_FIPS_Code  Strata_ID_Number  RHI_LBW_Ind  \
# count      3141.000000       3141.000000       3141.000000  3141.000000
# mean         30.304680        103.716651         44.696275     6.288443
# std          15.134423        107.999484         25.118434     1.498691
# min           1.000000          1.000000          1.000000    -2.000000
# 25%          18.000000         35.000000         23.000000     5.000000
# 50%          29.000000         79.000000         44.000000     6.000000
# 75%          45.000000        133.000000         66.000000     8.000000
# max          56.000000        840.000000         88.000000     8.000000
#
#        RHI_VLBW_Ind  RHI_Premature_Ind  RHI_Under_18_Ind  RHI_Over_40_Ind  \
# count   3141.000000        3141.000000       3141.000000      3141.000000
# mean       5.902897           6.338746          6.496657         5.837313
# std        2.284773           1.429397          1.733082         1.820606
# ...

# %%
df.describe(include=['object'])
# Out:
#        CHSI_County_Name CHSI_State_Name CHSI_State_Abbr
# count              3141            3141            3141
# unique             1847              51              51
# top          Washington           Texas              TX
# freq                 32             254             254

# %%
columns_to_analyze = df.columns[df.columns.str.startswith('RHI')]
columns_to_analyze
# Out:
# Index(['RHI_LBW_Ind', 'RHI_VLBW_Ind', 'RHI_Premature_Ind', 'RHI_Under_18_Ind',
#        'RHI_Over_40_Ind', 'RHI_Unmarried_Ind', 'RHI_Late_Care_Ind',
#        'RHI_Infant_Mortality_Ind', 'RHI_IM_Wh_Non_Hisp_Ind',
#        'RHI_IM_Bl_Non_Hisp_Ind', 'RHI_IM_Hisp_Ind', 'RHI_IM_Neonatal_Ind',
#        'RHI_IM_Postneonatal_Ind', 'RHI_Brst_Cancer_Ind', 'RHI_Col_Cancer_Ind',
#        'RHI_CHD_Ind', 'RHI_Homicide_Ind', 'RHI_Lung_Cancer_Ind', 'RHI_MVA_Ind',
#        'RHI_Stroke_Ind', 'RHI_Suicide_Ind', 'RHI_Injury_Ind'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.scatter(columns_to_analyze, df[columns_to_analyze].mean(), marker='x')
plt.xlabel('Death Cause Name')
plt.ylabel('Mean of Death index')
plt.xticks(columns_to_analyze, rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# ### 🤔 looks like 'non hispanic' have low death rate index. 'Homicide is also low'.
# ### Coronary Heart Disease (CHD) and Stroke have Very High death index than other

# %%
# lets see about CHD and Stroke

# %%
df.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
# 3                1                 7             Bibb         Alabama
# 4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  RHI_LBW_Ind  RHI_VLBW_Ind  \
# 0              AL                29            8             8
# 1              AL                16            8             8
# 2              AL                51            8             8
# 3              AL                42            8             8
# 4              AL                28            7             8
#
#    RHI_Premature_Ind  RHI_Under_18_Ind  ...  RHI_IM_Postneonatal_Ind  \
# 0                  8                 8  ...                        8
# ...

# %%
df.groupby('CHSI_State_Name')['RHI_CHD_Ind', 'RHI_Stroke_Ind'].agg(np.mean)
# Out:
#                       RHI_CHD_Ind  RHI_Stroke_Ind
# CHSI_State_Name
# Alabama                  5.850746        7.179104
# Alaska                   4.703704        4.666667
# Arizona                  5.266667        5.533333
# Arkansas                 6.773333        7.360000
# California               6.155172        6.793103
# Colorado                 5.234375        4.890625
# Connecticut              5.875000        5.500000
# Delaware                 8.000000        5.333333
# District of Columbia     8.000000        5.000000
# Florida                  6.835821        6.029851
# Georgia                  6.226415        7.238994
# Hawaii                   3.800000        5.000000
# Idaho                    5.545455        6.568182
# Illinois                 6.892157        6.833333
# Indiana                  7.173913        7.260870
# Iowa                     7.060606        6.414141
# Kansas                   6.285714        6.342857
# ...

# %% [markdown]
# ### lets visualize this in plot

# %%
state_name = df['CHSI_State_Name'].unique()
state_name
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
plt.figure(figsize=(12, 8))
plt.bar(state_name, df.groupby('CHSI_State_Name')['RHI_CHD_Ind'].agg(np.mean), color='r')
plt.plot(state_name, df.groupby('CHSI_State_Name')['RHI_Stroke_Ind'].agg(np.mean), color='b')
plt.xlabel('State Name')
plt.ylabel('Mean of death Index')
plt.xticks(state_name, rotation=90)
plt.show()

# %% [markdown]
# # looks similar in all the states

# %%
df.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
# 3                1                 7             Bibb         Alabama
# 4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  RHI_LBW_Ind  RHI_VLBW_Ind  \
# 0              AL                29            8             8
# 1              AL                16            8             8
# 2              AL                51            8             8
# 3              AL                42            8             8
# 4              AL                28            7             8
#
#    RHI_Premature_Ind  RHI_Under_18_Ind  ...  RHI_IM_Postneonatal_Ind  \
# 0                  8                 8  ...                        8
# ...

# %% [markdown]
# # lets see for cancers

# %%
df.columns
# Out:
# Index(['State_FIPS_Code', 'County_FIPS_Code', 'CHSI_County_Name',
#        'CHSI_State_Name', 'CHSI_State_Abbr', 'Strata_ID_Number', 'RHI_LBW_Ind',
#        'RHI_VLBW_Ind', 'RHI_Premature_Ind', 'RHI_Under_18_Ind',
#        'RHI_Over_40_Ind', 'RHI_Unmarried_Ind', 'RHI_Late_Care_Ind',
#        'RHI_Infant_Mortality_Ind', 'RHI_IM_Wh_Non_Hisp_Ind',
#        'RHI_IM_Bl_Non_Hisp_Ind', 'RHI_IM_Hisp_Ind', 'RHI_IM_Neonatal_Ind',
#        'RHI_IM_Postneonatal_Ind', 'RHI_Brst_Cancer_Ind', 'RHI_Col_Cancer_Ind',
#        'RHI_CHD_Ind', 'RHI_Homicide_Ind', 'RHI_Lung_Cancer_Ind', 'RHI_MVA_Ind',
#        'RHI_Stroke_Ind', 'RHI_Suicide_Ind', 'RHI_Injury_Ind'],
#       dtype='object')

# %%
col_cancers = ['RHI_Brst_Cancer_Ind', 'RHI_Col_Cancer_Ind', 'RHI_Lung_Cancer_Ind']
df[col_cancers].mean()
# Out:
# RHI_Brst_Cancer_Ind    5.642152
# RHI_Col_Cancer_Ind     6.136581
# RHI_Lung_Cancer_Ind    6.438395
# dtype: float64

# %% [markdown]
# # Lung cancer > colonal cancer > breast cancer

# %%
# lets see death index of these cancers in diff states

df.groupby('CHSI_State_Name')[col_cancers].agg(np.mean)
# Out:
#                       RHI_Brst_Cancer_Ind  RHI_Col_Cancer_Ind  \
# CHSI_State_Name
# Alabama                          6.611940            5.805970
# Alaska                           0.888889            3.666667
# Arizona                          5.733333            5.600000
# Arkansas                         6.186667            6.746667
# California                       5.396552            5.465517
# Colorado                         3.125000            4.015625
# Connecticut                      6.500000            5.875000
# Delaware                         6.333333            7.333333
# District of Columbia             8.000000            8.000000
# Florida                          5.686567            5.940299
# Georgia                          5.603774            5.767296
# Hawaii                           3.800000            4.000000
# Idaho                            4.750000            3.818182
# Illinois                         6.235294            7.529412
# ...

# %% [markdown]
# # We can plot this to give eye some relief from these numbers 😁

# %%
plt.figure(figsize=(12, 5))
plt.scatter(state_name, df.groupby('CHSI_State_Name')['RHI_Brst_Cancer_Ind'].agg(np.mean), marker='o')
plt.plot(state_name, df.groupby('CHSI_State_Name')['RHI_Col_Cancer_Ind'].agg(np.mean), color='b')
plt.scatter(state_name, df.groupby('CHSI_State_Name')['RHI_Lung_Cancer_Ind'].agg(np.mean), marker='x')
plt.xlabel('State Name')
plt.ylabel('Mean of death Index')
plt.xticks(state_name, rotation=90)
plt.legend(['RHI_Lung_Cancer_Ind', 'RHI_Col_Cancer_Ind', 'RHI_Brst_Cancer_Ind'])
plt.show()

# %% [markdown]
# ## Alaska have very low breast cancer death index than other states``

# %%
df.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
# 3                1                 7             Bibb         Alabama
# 4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  RHI_LBW_Ind  RHI_VLBW_Ind  \
# 0              AL                29            8             8
# 1              AL                16            8             8
# 2              AL                51            8             8
# 3              AL                42            8             8
# 4              AL                28            7             8
#
#    RHI_Premature_Ind  RHI_Under_18_Ind  ...  RHI_IM_Postneonatal_Ind  \
# 0                  8                 8  ...                        8
# ...

# %%
df.columns
# Out:
# Index(['State_FIPS_Code', 'County_FIPS_Code', 'CHSI_County_Name',
#        'CHSI_State_Name', 'CHSI_State_Abbr', 'Strata_ID_Number', 'RHI_LBW_Ind',
#        'RHI_VLBW_Ind', 'RHI_Premature_Ind', 'RHI_Under_18_Ind',
#        'RHI_Over_40_Ind', 'RHI_Unmarried_Ind', 'RHI_Late_Care_Ind',
#        'RHI_Infant_Mortality_Ind', 'RHI_IM_Wh_Non_Hisp_Ind',
#        'RHI_IM_Bl_Non_Hisp_Ind', 'RHI_IM_Hisp_Ind', 'RHI_IM_Neonatal_Ind',
#        'RHI_IM_Postneonatal_Ind', 'RHI_Brst_Cancer_Ind', 'RHI_Col_Cancer_Ind',
#        'RHI_CHD_Ind', 'RHI_Homicide_Ind', 'RHI_Lung_Cancer_Ind', 'RHI_MVA_Ind',
#        'RHI_Stroke_Ind', 'RHI_Suicide_Ind', 'RHI_Injury_Ind'],
#       dtype='object')

# %% [markdown]
# # Premature Vs Low Born Weight Vs Under 18 Death

# %%
child_death = ['RHI_LBW_Ind', 'RHI_Premature_Ind', 'RHI_Infant_Mortality_Ind']
df.groupby('CHSI_State_Name')[child_death].agg(np.mean)
# Out:
#                       RHI_LBW_Ind  RHI_Premature_Ind  RHI_Infant_Mortality_Ind
# CHSI_State_Name
# Alabama                  7.731343           7.716418                  7.298507
# Alaska                   4.481481           5.259259                  4.629630
# Arizona                  5.133333           6.266667                  6.000000
# Arkansas                 6.720000           6.613333                  6.946667
# California               5.068966           5.103448                  5.258621
# Colorado                 7.109375           6.265625                  4.546875
# Connecticut              6.250000           5.000000                  5.875000
# Delaware                 7.000000           7.333333                  8.000000
# District of Columbia     8.000000           8.000000                  8.000000
# Florida                  6.626866           6.626866                  6.656716
# Georgia                  7.069182           6.547170                  6.666667
# ...

# %%
df.pivot_table(child_death, ['CHSI_State_Name'], aggfunc='mean')
# Out:
#                       RHI_Infant_Mortality_Ind  RHI_LBW_Ind  RHI_Premature_Ind
# CHSI_State_Name
# Alabama                               7.298507     7.731343           7.716418
# Alaska                                4.629630     4.481481           5.259259
# Arizona                               6.000000     5.133333           6.266667
# Arkansas                              6.946667     6.720000           6.613333
# California                            5.258621     5.068966           5.103448
# Colorado                              4.546875     7.109375           6.265625
# Connecticut                           5.875000     6.250000           5.000000
# Delaware                              8.000000     7.000000           7.333333
# District of Columbia                  8.000000     8.000000           8.000000
# Florida                               6.656716     6.626866           6.626866
# Georgia                               6.666667     7.069182           6.547170
# ...

# %%
# df.groupby('CHSI_State_Name')[child_death].agg(np.mean)
# df.pivot_table(child_death, ['CHSI_State_Name'], aggfunc='mean')
# both gave same result
